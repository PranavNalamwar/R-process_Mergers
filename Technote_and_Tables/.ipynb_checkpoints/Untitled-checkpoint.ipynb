# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('testing_stuff.csv')

# %%
configs = data['Electron Configuration']
elements = data['Element']

# %%
for i in range(len(configs)):
    for j in range(len(configs)):
        if configs[i] == configs[j] and i!=j and i<j:
            print(i,' ',j)
# Out:
# 39   43
# 40   44

# %%
print(configs[39], elements[39])
print(configs[43],elements[43])
# Out:
# [Xe]4f146s2 Ytterbium
# [Xe]4f146s2 Lutetium

# %%
print(configs[40], elements[40])
print(configs[44],elements[44])
# Out:
# [Xe]4f146s Ytterbium
# [Xe]4f146s Lutetium

# %%
data2 = pd.read_csv('electon_configuration abundances.csv')

# %%
data2
# Out:
#                                               Element Electron Configuration  \
# 0                                           Lanthanum            [Xe] 5d 6s2
# 1                                           Lanthanum               [Xe] 5d2
# 2                                           Lanthanum                [Xe] 5d
# 3                                              Cerium         [Xe] 4f 5d 6s2
# 4                                              Cerium            [Xe] 4f 5d2
# 5                                              Cerium               [Xe] 4f2
# 6                                        Praseodymium           [Xe] 4f3 6s2
# 7                                        Praseodymium            [Xe] 4f3 6s
# 8                                        Praseodymium               [Xe] 4f3
# 9                                           Neodymium           [Xe] 4f4 6s2
# 10                                          Neodymium            [Xe ]4f4 6s
# ...
